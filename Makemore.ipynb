# %% [markdown]
# <a href="https://colab.research.google.com/github/Bilalk0804/Expriments/blob/main/Makemore.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
words=open('names.txt').read().splitlines()

# %%
words[:20]
# Out:
# ['emma',
#  'olivia',
#  'ava',
#  'isabella',
#  'sophia',
#  'charlotte',
#  'mia',
#  'amelia',
#  'harper',
#  'evelyn',
#  'abigail',
#  'emily',
#  'elizabeth',
#  'mila',
#  'ella',
#  'avery',
#  'sofia',
#  'camila',
#  'aria',
#  'scarlett']

# %%
len(words)
# Out:
# 32033

# %%
min(len(w) for w in words)
# Out:
# 2

# %%
longest_word = max(words, key=len)
print(f"The longest word is: '{longest_word}'")
# Out:
# The longest word is: 'muhammadibrahim'

# %%
print(max(len(w) for w in words))
# Out:
# 15

# %%
for w in words:
    for c1==c2 in w:
